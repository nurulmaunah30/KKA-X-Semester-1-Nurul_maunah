# %% [markdown]
# <a href="https://colab.research.google.com/github/nurulmaunah30/KKA-X-Semester-1-Nurul_maunah/blob/main/Aplikasi_Kalkulator_Sederhana_Nurul_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Kalkulator Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")

# %% [markdown]
# #Kalkulator Menghitung Volume Bangun Bola

# %%
jari_jari = int(input("Masukkan jari_jari dari bola cm): "))
luas = 4*22/7*jari_jari**2

print(f"\nLuas dari bola yaitu {Luas}cm^2")

# %%
jari_jari =int(input("Masukkan jari_jari dari bola(cm): "))
volume = 4/3*22/7*jari_jari**3

print(f"\nVolume dari bola yaitu {volume} cm^3")
